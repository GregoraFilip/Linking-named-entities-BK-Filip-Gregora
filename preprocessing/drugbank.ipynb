# %%
import pandas as pd

# %%
atc_drug_bank = pd.read_csv("../databaze/drugbank_to_atc.csv", index_col=[0])
atc_drug_bank
# Out:
#           atc                 name  \
# 0     B01AE02            Lepirudin
# 1     L01FE01            Cetuximab
# 2     R05CB13         Dornase alfa
# 3     L01XX29  Denileukin diftitox
# 4     L04AB01           Etanercept
# ...       ...                  ...
# 5510  G03FB05            Estradiol
# 5511  G03FB10            Estradiol
# 5512  G03FA01            Estradiol
# 5513  G03EA03            Estradiol
# 5514  G03FA09            Estradiol
#
#                                             description     code
# 0     Lepirudin is a recombinant hirudin formed by 6...  DB00001
# 1     Cetuximab is a recombinant chimeric human/mous...  DB00002
# 2     Dornase alfa is a biosynthetic form of human d...  DB00003
# 3     A recombinant DNA-derived cytotoxic protein co...  DB00004
# 4     Dimeric fusion protein consisting of the extra...  DB00005
# ...                                                 ...      ...
# 5510  Estradiol is a naturally occurring hormone cir...  DB00783
# 5511  Estradiol is a naturally occurring hormone cir...  DB00783
# 5512  Estradiol is a naturally occurring hormone cir...  DB00783
# 5513  Estradiol is a naturally occurring hormone cir...  DB00783
# 5514  Estradiol is a naturally occurring hormone cir...  DB00783
#
# [5515 rows x 4 columns]

# %%
print(len(atc_drug_bank))
print(len(atc_drug_bank.drop_duplicates()))
print()

print(len(atc_drug_bank["atc"].drop_duplicates()))
# Out:
# 5515
# 5515
#
# 4910

# %%
atc_drug_bank[atc_drug_bank["atc"].duplicated(keep=False)].sample(10, random_state=42)
# Out:
#           atc                  name  \
# 4792  A11GB01         Ascorbic acid
# 4216  A11GB01     Calcium Phosphate
# 5073  C10BA06             Ezetimibe
# 4153  J05AP52             Dasabuvir
# 3538  J01AA20           Lymecycline
# 4685  G01AE10  Sulfathiazole sodium
# 5020  N02AJ07               Codeine
# 3621  A02BD03          Lansoprazole
# 5042  G01AE10        Sulfamethizole
# 4411  A10BD06           Glimepiride
#
#                                             description          code
# 4792  A six carbon compound related to glucose. It i...       DB00126
# 4216  Calcium phosphate is typically available as an...       DB11348
# 5073  Ezetimibe is a lipid-lowering compound that in...       DB00973
# 4153  Dasabuvir is a direct acting antiviral medicat...       DB09183
# 3538  Lymecycline is a broad-spectrum second-generat...       DB00256
# 4685                                                NaN  DBSALT000848
# 5020  The relief of pain (analgesia) is a primary go...       DB00318
# 3621  Lansoprazole marketed under the brand Prevacid...       DB00448
# 5042               A sulfathiazole antibacterial agent.       DB00576
# 4411  First introduced in 1995, glimepiride is a mem...       DB00222

# %%
atc_drug_bank["atc"].value_counts().head()
# Out:
# G01AE10    69
# J01CR50    26
# J01AA20    13
# G01AF20    11
# N05CB01    11
# Name: atc, dtype: int64
